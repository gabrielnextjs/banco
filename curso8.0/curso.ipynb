# %%
media = 0
media_requrida = int(input("Media requerida: "))

while media < media_requrida:
    print(f"Media atual {media} no entanto a requerida e {media_requrida}")
    media = media + 1
print(f"A media de {media_requrida} foi batida")
# Out:
# Media atual 0 no entanto a requerida e 15
# Media atual 1 no entanto a requerida e 15
# Media atual 2 no entanto a requerida e 15
# Media atual 3 no entanto a requerida e 15
# Media atual 4 no entanto a requerida e 15
# Media atual 5 no entanto a requerida e 15
# Media atual 6 no entanto a requerida e 15
# Media atual 7 no entanto a requerida e 15
# Media atual 8 no entanto a requerida e 15
# Media atual 9 no entanto a requerida e 15
# Media atual 10 no entanto a requerida e 15
# Media atual 11 no entanto a requerida e 15
# Media atual 12 no entanto a requerida e 15
# Media atual 13 no entanto a requerida e 15
# Media atual 14 no entanto a requerida e 15
# A media de 15 foi batida
