# %%
n1 = int(input("Insira o primeiro numero: "))
n2 = int(input("Insira o segundo numero: "))

print(n1 + n2)
print(n1 - n2)
print(n1 * n2)
print(n1 / n2)

# %%
nome = input("Insira seu nome: ")
print(nome)

# %%
while True:
    try:
        num1 = int(input("Insira o numero 1"))
        num2 = int(input("Insira o numero 2"))
        break
    except ValueError:
        print("Digite apenas numeros")

resultado = num1 + num2

print(resultado)

# %%
def ler_numero(mensagem, tipo= float):
    while True:
        try:
            return tipo(input(mensagem).replace(",","."))
        except ValueError:
            print("Digite apenas numeros")

num1 = ler_numero("Insira o numero 1")
num2 = ler_numero("Insira o numero 2")

def somar(num1, num2):
    resultado = num1 + num2
    resultado = round(resultado , 2)
    return resultado

resultado = somar(num1, num2)


print(f"O reultado da soma e {resultado}")

# %%
def ler_numero(mensagem, tipo= float):
    while True:
        try:
            return tipo(input(mensagem).replace(",","."))
        except ValueError:
            print("Digite apenas numeros")

nome = input("Insira seu nome: ")
idade = ler_numero("Insira sua idade:",int)
liberado = False

def validate_age(idade):
    if idade >= 18:
        return True
    else:
        return False

liberado = validate_age(idade)

if liberado == True:
    print("Acesso liberado")
elif liberado == False:
    print("Acesso negado")

# %%
def ler_numero(mensagem, tipo= float):
    while True:
        try:
            return tipo(input(mensagem).replace(",","."))
        except ValueError:
            print("Digite apenas numeros")

nome = input("Insira seu nome: ")
idade = ler_numero("Insira sua idade:",int)

def validar_idade(idade):
    return idade >= 18


liberado = validar_idade(idade)

def purchase_product(ler_numero, idade, validar_idade):
    produto = 0
    while produto != 3:
        produto = ler_numero("Insira o numero do produto o qual deseja comprar: \n" 
    "[1] salame\n [2] cigarro\n [3] sair\n", int)
        if produto == 1:
            print(f"Produto comprado")
        elif produto == 2:
            if validar_idade(idade):
                print(f"Produto comprado")
            else:
                print("Voce nao tem idade suficiente")
        elif produto == 3:
            print("Voce saiu...")
            break
        else:
            print("Esta opcao nao existe")

purchase_product(ler_numero, idade, validar_idade)
# Out:
# Digite apenas numeros
# Voce saiu...
