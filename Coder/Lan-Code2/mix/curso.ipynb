# %%
from utils import premen , preven

def check_age(idade):

    if idade >= 18:
        return True
    else:
        return False

p_idade = preven("Insira sua idade")

if check_age(p_idade):
    print("Entre")
else:
    print("Saia")
# Out:
# Saia

# %%
name = input("Insira seu nome: ")
Age = preven("Insira sua idade: ")

dados_back = []
dados = {"Nome":{name}, "Idade":{Age}}
dados_back.append(dados)

if Age >= 18:
    print("Seja bem vindo")
else:
    print("Voce nao pode entrar aqui")

# %%
import time

contador = 10

while contador >= 1:
    print(f"Contagem atual: {contador}")
    contador -= 1
    time.sleep(1)
else: 
    print("O contador chegou ao fim")

# %%
senha = "Gabrir1410"
tentativa = ""
erro = 0

while tentativa != senha and erro != 3:
    tentativa = input("Digite a senha: ")
    if senha == tentativa:
        print("Acesso liberado!")
    else:
        print("Senha incorreta")
        erro = erro + 1

if erro == 3:
    print("Acesso Bloqueado!")

# %%
compras = ["Arroz", "Feijao","Mandioca" ]

for item in compras:
    time.sleep(1)
    print(f"Voce precisa comprar:",item, end="\r")

# %%
numeros = [5,6,7,8,3,2,4]
for numero in numeros:
    if numero % 2 == 0:
        continue
    print(numero)

# %%
def ola(user):
    print(f"Ola, {user}!")

nome = input("Informe seu nome: ")
ola(nome)
# Out:
# Ola, Gabriel!

# %%
def soma(n1,n2):
    resultado = n1 + n2
    print(f"O resultado de {n1} + {n2} e {resultado}")

pergunta = preven("Insira o primeiro numero: ")
pergunta_2 = preven("Insira o segundo numero: ")

soma(pergunta , pergunta_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2     resultado = n1 + n2
#       3     print(f"O resultado de {n1} + {n2} e {resultado}")
# ----> 5 pergunta = preven("Insira o primeiro numero: ")
#       6 pergunta_2 = preven("Insira o segundo numero: ")
#       8 soma(pergunta , pergunta_2)
#
# NameError: name 'preven' is not defined
